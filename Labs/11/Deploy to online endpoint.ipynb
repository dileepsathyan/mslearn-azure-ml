# %% [markdown]
# # Deploy to an online endpoint
#
# To consume a model from an application, you can deploy the model to an online endpoint. You'll create an MLflow model from local files and test the endpoint.
#
# ## Before you start
#
# You'll need the latest version of the  **azure-ai-ml** package to run the code in this notebook. Run the cell below to verify that it is installed.
#
# > **Note**:
# > If the **azure-ai-ml** package is not installed, run `pip install azure-ai-ml` to install it.

# %%
pip show azure-ai-ml
# Out:
# Name: azure-ai-ml
# Version: 1.30.0
# Summary: Microsoft Azure Machine Learning Client Library for Python
# Home-page: https://github.com/Azure/azure-sdk-for-python
# Author: Microsoft Corporation
# Author-email: azuresdkengsysadmins@microsoft.com
# License: MIT License
# Location: c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages
# Requires: azure-common, azure-core, azure-mgmt-core, azure-monitor-opentelemetry, azure-storage-blob, azure-storage-file-datalake, azure-storage-file-share, colorama, isodate, jsonschema, marshmallow, pydash, pyjwt, pyyaml, strictyaml, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect to your workspace
#
# With the required SDK packages installed, now you're ready to connect to your workspace.
#
# To connect to a workspace, we need identifier parameters - a subscription ID, resource group name, and workspace name. Since you're working with a compute instance, managed by Azure Machine Learning, you can use the default values to connect to the workspace.

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient

try:
    credential = DefaultAzureCredential()
    # Check if given credential can get token successfully.
    credential.get_token("https://management.azure.com/.default")
except Exception as ex:
    # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
    credential = InteractiveBrowserCredential()

# %%
# Get a handle to workspace
ml_client = MLClient.from_config(credential=credential)
# Out:
# Found the config file in: .\config.json
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %% [markdown]
# ## Define and create an endpoint
#
# Ultimately, the goal is to deploy a model to an endpoint. Therefore, you first need to create an endpoint. The endpoint will be a HTTPS endpoint that an application can call to receive predictions from the model. An application can consume an endpoint by using its URI, and authenticating with a key or token.
#
# Run the following cell to define the endpoint. Note that the name of the endpoint has to be unique. You'll use the `datetime` function to generate a unique name.

# %%
from azure.ai.ml.entities import ManagedOnlineEndpoint
import datetime

online_endpoint_name = "endpoint-" + datetime.datetime.now().strftime("%m%d%H%M%f")

# create an online endpoint
endpoint = ManagedOnlineEndpoint(
    name=online_endpoint_name,
    description="Online endpoint for MLflow diabetes model",
    auth_mode="key",
)

# %% [markdown]
# Next, you'll create the endpoint by running the following cell. This may take several minutes. While your endpoint is being created, you can read about [what are Azure Machine Learning endpoints](https://learn.microsoft.com/azure/machine-learning/concept-endpoints).

# %%
ml_client.begin_create_or_update(endpoint).result()
# Out:
# ManagedOnlineEndpoint({'public_network_access': 'Enabled', 'provisioning_state': 'Succeeded', 'scoring_uri': 'https://endpoint-12111007459602.westeurope.inference.ml.azure.com/score', 'openapi_uri': 'https://endpoint-12111007459602.westeurope.inference.ml.azure.com/swagger.json', 'name': 'endpoint-12111007459602', 'description': 'Online endpoint for MLflow diabetes model', 'tags': {}, 'properties': {'createdBy': 'Dileep Sathyan', 'createdAt': '2025-12-11T15:07:54.204066+0000', 'lastModifiedAt': '2025-12-11T15:07:54.204066+0000', 'azureml.onlineendpointid': '/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/resourcegroups/rg-dp100-lab11/providers/microsoft.machinelearningservices/workspaces/mlw-dp100-lab11/onlineendpoints/endpoint-12111007459602', 'AzureAsyncOperationUri': 'https://management.azure.com/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/providers/Microsoft.MachineLearningServices/locations/westeurope/mfeOperationsStatus/oeidp:baf0d846-9e72-4041-b906-68a36e1b142e:6f522a48-5cd1-436a-971d-57cc92c02a31?api-version=2022-02-01-preview'}, 'print_as_yaml': False, 'id': '/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/resourceGroups/rg-dp100-lab11/providers/Microsoft.MachineLearningServices/workspaces/mlw-dp100-lab11/onlineEndpoints/endpoint-12111007459602', 'Resource__source_path': '', 'base_path': 'c:\\Users\\Dsathyan\\Documents\\GitHub\\mslearn-azure-ml\\Labs\\11', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x00000150C1F07BC0>, 'auth_mode': 'key', 'location': 'westeurope', 'identity': <azure.ai.ml.entities._credentials.IdentityConfiguration object at 0x00000150C168F680>, 'traffic': {}, 'mirror_traffic': {}, 'kind': 'Managed'})

# %% [markdown]
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the endpoint is created successfully before continuing! A green notification should appear in the studio. </p>
#
# ## Configure the deployment
#
# You can deploy multiple models to an endpoint. This is mostly useful when you want to update the deployed model while keeping the current model in production. You'll need to configure the deployment to specify which model needs to be deployed to an endpoint. In the following cell, you'll refer to the model trained and stored in the local `model` folder (stored in the same folder as this notebook). Note that since you're working with an MLflow model, you don't need to specify the environment or scoring script.
#
# You'll also specify the infrastructure needed for the model to be deployed.

# %%
from azure.ai.ml.entities import Model, ManagedOnlineDeployment
from azure.ai.ml.constants import AssetTypes

# create a blue deployment
model = Model(
    path="./model",
    type=AssetTypes.MLFLOW_MODEL,
    description="my sample mlflow model",
)

blue_deployment = ManagedOnlineDeployment(
    name="blue",
    endpoint_name=online_endpoint_name,
    model=model,
    instance_type="Standard_D2as_v4",
    instance_count=1,
)

# %% [markdown]
# ## Create the deployment
#
# Finally, you can actually deploy the model to the endpoint by running the following cell:

# %%
# Replace endpoint_name and deployment_name with your values
endpoint = ml_client.online_endpoints.get(name=online_endpoint_name)
print("Endpoint:", endpoint.name, "state:", getattr(endpoint, "provisioning_state", None))
deployment = ml_client.online_deployments.get(name="blue", endpoint_name=online_endpoint_name)
print("Deployment object:\n", deployment)
# Out:
# Endpoint: endpoint-12111007459602 state: Succeeded
# Deployment object:
#  app_insights_enabled: false
# creation_context:
#   created_at: '2025-12-11T15:12:42.312017+00:00'
#   created_by: Dileep Sathyan
#   last_modified_at: '2025-12-11T15:12:42.312017+00:00'
# egress_public_network_access: enabled
# endpoint_name: endpoint-12111007459602
# environment: azureml:/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/resourceGroups/rg-dp100-lab11/providers/Microsoft.MachineLearningServices/workspaces/mlw-dp100-lab11/environments/a775c7ce844e0219596b74454997c794416e583a2d724efafb4dbd8fda08088a/versions/ad501366d19da7f0aeba342b105a0e0966e38d0059ffda24db1daaae651313fa
# environment_variables:
#   AZUREML_MODEL_DIR: /var/azureml-app/azureml-models/a775c7ce844e0219596b74454997c794416e583a2d724efafb4dbd8fda08088a/1
#   MLFLOW_MODEL_FOLDER: model
# id: /subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/resourceGroups/rg-dp100-lab11/providers/Microsoft.MachineLearningServices/workspaces/mlw-dp100-lab11/onlineEndpoints/endpoint-12111007459602/deployments/blue
# instance_count: 1
# instance_type: Standard_D2as_v4
# liveness_probe:
#   failure_threshold: 30
#   initial_delay: 10
#   period: 10
#   success_threshold: 1
#   timeout: 2
# model: azureml:/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/resourceGroups/rg-dp100-lab11/providers/Microsoft.MachineLearningServices/workspaces/mlw-dp100-lab11/models/a775c7ce844e0219596b74454997c794416e583a2d724efafb4dbd8fda08088a/versions/1
# name: blue
# properties:
#   AzureAsyncOperationUri: https://management.azure.com/subscriptions/38245d22-4620-4106-9d08-a07ed74df31e/providers/Microsoft.MachineLearningServices/locations/westeurope/mfeOperationsStatus/odidp:baf0d846-9e72-4041-b906-68a36e1b142e:dd9fdbfb-3bd5-4da9-be96-6497f5d95d77?api-version=2023-04-01-preview
# provisioning_state: Failed
# readiness_probe:
#   failure_threshold: 30
#   initial_delay: 10
#   period: 10
#   success_threshold: 1
#   timeout: 2
# request_settings:
#   max_concurrent_requests_per_instance: 1
#   request_timeout_ms: 5000
# scale_settings:
#   type: default
# tags: {}
# type: managed

# %%
ml_client.online_deployments.begin_create_or_update(blue_deployment).result()
# Out:
# Check: endpoint endpoint-12111007459602 exists
# ...............................................................................................
# ---------------------------------------------------------------------------
# OperationFailed                           Traceback (most recent call last)
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\base_polling.py:805, in LROBasePolling.run(self)
#     804 try:
# --> 805     self._poll()
#     807 except BadStatus as err:
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\base_polling.py:837, in LROBasePolling._poll(self)
#     836 if _failed(self.status()):
# --> 837     raise OperationFailed("Operation failed or canceled")
#     839 final_get_url = self._operation.get_final_get_url(self._pipeline_response)
#
# OperationFailed: Operation failed or canceled
#
# The above exception was the direct cause of the following exception:
#
# HttpResponseError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ml_client.online_deployments.begin_create_or_update(blue_deployment).result()
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\_poller.py:326, in LROPoller.result(self, timeout)
#     317 def result(self, timeout: Optional[float] = None) -> PollingReturnType_co:
#     318     """Return the result of the long running operation, or
#     319     the result available after the specified timeout.
#     320
#    (...)    324     :raises ~azure.core.exceptions.HttpResponseError: Server problem with the query.
#     325     """
# --> 326     self.wait(timeout)
#     327     return self._polling_method.resource()
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\_poller.py:345, in LROPoller.wait(self, timeout)
#     341 self._thread.join(timeout=timeout)
#     342 try:
#     343     # Let's handle possible None in forgiveness here
#     344     # https://github.com/python/mypy/issues/8165
# --> 345     raise self._exception  # type: ignore
#     346 except TypeError:  # Was None
#     347     pass
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\_poller.py:250, in LROPoller._start(self)
#     246 """Start the long running operation.
#     247 On completion, runs any callbacks.
#     248 """
#     249 try:
# --> 250     self._polling_method.run()
#     251 except AzureError as error:
#     252     if not error.continuation_token:
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\polling\base_polling.py:820, in LROBasePolling.run(self)
#     813     raise HttpResponseError(
#     814         response=self._pipeline_response.http_response,
#     815         message=str(err),
#     816         error=err,
#     817     ) from err
#     819 except OperationFailed as err:
# --> 820     raise HttpResponseError(response=self._pipeline_response.http_response, error=err) from err
#
# HttpResponseError: (BadArgument) User container has crashed or terminated: Liveness probe failed: HTTP probe failed with statuscode: 502. Please see troubleshooting guide, available here: https://aka.ms/oe-tsg#error-badargument
# Code: BadArgument
# Message: User container has crashed or terminated: Liveness probe failed: HTTP probe failed with statuscode: 502. Please see troubleshooting guide, available here: https://aka.ms/oe-tsg#error-badargument

# %% [markdown]
# The deployment of the model may take 10-15 minutes. While waiting for the model to be deployed, you can learn more about [managed endpoints in this video](https://www.youtube.com/watch?v=SxFGw_OBxNM&ab_channel=MicrosoftDeveloper).
#
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the deployment is completed before continuing! A green notification should appear in the studio.</p>
#
# Since you only have one model deployed to the endpoint, you want this deployment to take 100% of the traffic. If you deploy multiple models to the endpoint, you could use the same approach to distribute traffic across the deployed models.

# %%
# blue deployment takes 100 traffic
endpoint.traffic = {"blue": 100}
ml_client.begin_create_or_update(endpoint).result()
# Out:
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # blue deployment takes 100 traffic
#       2 endpoint.traffic = {"blue": 100}
# ----> 3 ml_client.begin_create_or_update(endpoint).result()
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\_ml_client.py:1342, in MLClient.begin_create_or_update(self, entity, **kwargs)
#    1323 def begin_create_or_update(
#    1324     self,
#    1325     entity: R,
#    1326     **kwargs,
#    1327 ) -> LROPoller[R]:
#    1328     """Creates or updates an Azure ML resource asynchronously.
#    1329
#    1330     :param entity: The resource to create or update.
#    (...)   1339         , ~azure.ai.ml.entities.BatchEndpoint, ~azure.ai.ml.entities.Schedule]]
#    1340     """
# -> 1342     return _begin_create_or_update(entity, self._operation_container.all_operations, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\functools.py:907, in singledispatch.<locals>.wrapper(*args, **kw)
#     903 if not args:
#     904     raise TypeError(f'{funcname} requires at least '
#     905                     '1 positional argument')
# --> 907 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\_ml_client.py:1442, in _(entity, operations, *args, **kwargs)
#    1439 @_begin_create_or_update.register(OnlineEndpoint)
#    1440 def _(entity: OnlineEndpoint, operations, *args, **kwargs):
#    1441     module_logger.debug("Creating or updating online_endpoints")
# -> 1442     return operations[AzureMLResourceType.ONLINE_ENDPOINT].begin_create_or_update(entity, **kwargs)
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\operations\_online_endpoint_operations.py:263, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     261     log_and_raise_error(ex)
#     262 else:
# --> 263     raise ex
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\operations\_online_endpoint_operations.py:258, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     255         return poller
#     257     except Exception as ex:
# --> 258         raise ex
#     259 except Exception as ex:  # pylint: disable=W0718
#     260     if isinstance(ex, (ValidationException, SchemaValidationError)):
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\operations\_online_endpoint_operations.py:247, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     242     if hasattr(endpoint_resource.properties, "compute"):
#     243         endpoint_resource.properties.compute = orchestrators.get_asset_arm_id(
#     244             endpoint_resource.properties.compute,
#     245             azureml_type=AzureMLResourceType.COMPUTE,
#     246         )
# --> 247     poller = self._online_operation.begin_create_or_update(
#     248         resource_group_name=self._resource_group_name,
#     249         workspace_name=self._workspace_name,
#     250         endpoint_name=endpoint.name,
#     251         body=endpoint_resource,
#     252         cls=lambda response, deserialized, headers: OnlineEndpoint._from_rest_object(deserialized),
#     253         **self._init_kwargs,
#     254     )
#     255     return poller
#     257 except Exception as ex:
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\_restclient\v2022_02_01_preview\operations\_online_endpoints_operations.py:921, in OnlineEndpointsOperations.begin_create_or_update(self, resource_group_name, workspace_name, endpoint_name, body, **kwargs)
#     919 cont_token = kwargs.pop('continuation_token', None)  # type: Optional[str]
#     920 if cont_token is None:
# --> 921     raw_result = self._create_or_update_initial(
#     922         resource_group_name=resource_group_name,
#     923         workspace_name=workspace_name,
#     924         endpoint_name=endpoint_name,
#     925         body=body,
#     926         content_type=content_type,
#     927         cls=lambda x,y,z: x,
#     928         **kwargs
#     929     )
#     930 kwargs.pop('error_map', None)
#     932 def get_long_running_output(pipeline_response):
#
# File c:\Users\Dsathyan\Documents\GitHub\mslearn-azure-ml\Labs\.azureml-venv\Lib\site-packages\azure\ai\ml\_restclient\v2022_02_01_preview\operations\_online_endpoints_operations.py:856, in OnlineEndpointsOperations._create_or_update_initial(self, resource_group_name, workspace_name, endpoint_name, body, **kwargs)
#     854 if response.status_code not in [200, 201]:
#     855     map_error(status_code=response.status_code, response=response, error_map=error_map)
# --> 856     raise HttpResponseError(response=response, error_format=ARMErrorFormat)
#     858 response_headers = {}
#     859 if response.status_code == 200:
#
# HttpResponseError: (BadRequest) The request is invalid.
# Code: BadRequest
# Message: The request is invalid.
# Exception Details:	(InferencingClientCallFailed) {"error":{"code":"Validation","message":"{\"errors\":{\"DeploymentWeights\":[\"The deployments [blue] on which you are trying to set the traffic are in a failed state and don't have ingress. Please fix the deployments and try again.\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-bedf03a179da01547c5c9ca5b0bdef5f-f991a6881a8f6789-01\"}"}}
# 	Code: InferencingClientCallFailed
# 	Message: {"error":{"code":"Validation","message":"{\"errors\":{\"DeploymentWeights\":[\"The deployments [blue] on which you are trying to set the traffic are in a failed state and don't have ingress. Please fix the deployments and try again.\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-bedf03a179da01547c5c9ca5b0bdef5f-f991a6881a8f6789-01\"}"}}
# Additional Information:Type: ComponentName
# Info: {
#     "value": "managementfrontend"
# }Type: Correlation
# Info: {
#     "value": {
#         "operation": "bedf03a179da01547c5c9ca5b0bdef5f",
#         "request": "54eb71400f47576e"
#     }
# }Type: Environment
# Info: {
#     "value": "westeurope"
# }Type: Location
# Info: {
#     "value": "westeurope"
# }Type: Time
# Info: {
#     "value": "2025-12-11T15:58:15.0079566+00:00"
# }

# %% [markdown]
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the blue deployment is configured before continuing! A green notification should appear in the studio. </p>
#
# ## Test the deployment
#
# Let's test the deployed model by invoking the endpoint. A JSON file with sample data is used as input. The trained model predicts whether a patient has diabetes or not, based on medical data like age, BMI, and the number of pregnancies. A `[0]` indicates a patient doesn't have diabetes. A `[1]` means a patient does have diabetes.

# %%
# test the blue deployment with some sample data
response = ml_client.online_endpoints.invoke(
    endpoint_name=online_endpoint_name,
    deployment_name="blue",
    request_file="sample-data.json",
)

if response[1]=='1':
    print("Diabetic")
else:
    print ("Not diabetic")

# %% [markdown]
# Optionally, you can change the values in the `sample-data.json` file to try and get a different prediction.

# %% [markdown]
# ## List endpoints
#
# Although you can view all endpoints in the Studio, you can also list all endpoints using the SDK:

# %%
endpoints = ml_client.online_endpoints.list()
for endp in endpoints:
    print(endp.name)
# Out:
# endpoint-12111007459602

# %% [markdown]
# ## Get endpoint details
#
# If you want more information about a specific endpoint, you can explore the details using the SDK too.

# %%
# Get the details for online endpoint
endpoint = ml_client.online_endpoints.get(name=online_endpoint_name)

# existing traffic details
print(endpoint.traffic)

# Get the scoring URI
print(endpoint.scoring_uri)
# Out:
# {'blue': 0}
# https://endpoint-12111007459602.westeurope.inference.ml.azure.com/score

# %% [markdown]
# ## Delete the endpoint and deployment
#
# As an endpoint is always available, it can't be paused to save costs. To avoid unnecessary costs, delete the endpoint.

# %%
ml_client.online_endpoints.begin_delete(name=online_endpoint_name)
# Out:
# .................................................................................
